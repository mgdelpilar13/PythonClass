# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
CollegeSalaries=pd.read_csv('/ct-professor-salaries (1).csv')

# %%
print(CollegeSalaries)
# First, I want to see all the data I just imported.
# Out:
#                                        College  Average All Pay  \
# 0                      Albertus Magnus College            68409
# 1                  Asnuntuck Community College            62190
# 2                    Capital Community College            63225
# 3         Central Connecticut State University            76617
# 4                          Connecticut College            86166
# 5         Eastern Connecticut State University            72819
# 6                         Fairfield University            91926
# 7                    Gateway Community College            69966
# 8                            Hartford Seminary            54387
# 9                  Holy Apostles College & Sem            29331
# 10                Housatonic Community College            55485
# 11                 Lincoln College New England            50733
# 12               LymeAcademy College Fine Arts            33813
# 13                Manchester Community College            67077
# ...

# %%
CollegeSalaries.describe().T
# Out:
#                      count          mean           std      min       25%  \
# Average All Pay       38.0  73487.605263  20924.994602  29331.0  63285.75
# Average Professor     37.0  89921.918919  28687.833767  32139.0  76995.00
# Associate Professor   37.0  69632.756757  16937.611909  32436.0  60183.00
# Assistant Professor   35.0  59753.028571  12185.649271  40095.0  51057.00
# Lecturer              33.0  54280.909091  17485.646786  10647.0  45315.00
#
#                          50%        75%       max
# Average All Pay      69187.5   78266.25  144378.0
# Average Professor    84456.0  105669.00  192546.0
# Associate Professor  67914.0   79263.00  117288.0
# Assistant Professor  56574.0   67680.00   95499.0
# Lecturer             51210.0   63000.00  104697.0

# %%
CollegeSalaries.shape
# Out:
# (38, 7)

# %%
CollegeSalaries.isnull().sum()
# I am going to see if there is a profession that has the least amount of null values in its column and use that information to create my new dataset.
# Out:
# College                0
# Average All Pay        0
# Average Professor      1
# Associate Professor    1
# Assistant Professor    3
# Lecturer               5
# City                   0
# dtype: int64

# %%
CollegeSalaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   College              38 non-null     object
#  1   Average All Pay      38 non-null     int64
#  2   Average Professor    37 non-null     float64
#  3   Associate Professor  37 non-null     float64
#  4   Assistant Professor  35 non-null     float64
#  5   Lecturer             33 non-null     float64
#  6   City                 38 non-null     object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 2.2+ KB

# %%
CollegeSalaries.groupby('City').count()
#Then, I want to see if there is a city that has more colleges than the rest so I can compare the schools within that city.
# Out:
#                College  Average All Pay  Average Professor  \
# City
# Bridgeport           3                3                  2
# Cromwell             1                1                  1
# Danbury              1                1                  1
# Danielson            1                1                  1
# Enfield              1                1                  1
# Fairfield            2                2                  2
# Farmington           1                1                  1
# Hamden               1                1                  1
# Hartford             4                4                  4
# Manchester           1                1                  1
# Middletown           2                2                  2
# New Britain          1                1                  1
# New Haven            4                4                  4
# New London           3                3                  3
# Norwalk              1                1                  1
# ...

# %%
Prof_Sal=CollegeSalaries[['City', 'College', 'Average Professor']]
# I want to create a subset from my original dataframe to just these three columns.

# %%
Prof_Sal.head()
# Out:
#           City                               College  Average Professor
# 0    New Haven               Albertus Magnus College            79533.0
# 1      Enfield           Asnuntuck Community College            80280.0
# 2     Hartford             Capital Community College            76905.0
# 3  New Britain  Central Connecticut State University            89910.0
# 4   New London                   Connecticut College           111186.0

# %%
Prof_Sal.plot(kind="bar", x="City", y="Average Professor")
# Out:
# <Axes: xlabel='City'>

# %%
City_Grouped = Prof_Sal.groupby('City').size()

# %%
print(City_Grouped)
# Out:
# City
# Bridgeport       3
# Cromwell         1
# Danbury          1
# Danielson        1
# Enfield          1
# Fairfield        2
# Farmington       1
# Hamden           1
# Hartford         4
# Manchester       1
# Middletown       2
# New Britain      1
# New Haven        4
# New London       3
# Norwalk          1
# Norwich          1
# Old Lyme         1
# Southington      1
# Storrs           1
# Waterbury        2
# West Hartford    2
# West Haven       1
# Willimantic      1
# Winsted          1
# dtype: int64

# %%
City_Sal = Prof_Sal.groupby('City')

# %%
print(City_Sal)
# Out:
# City
# Bridgeport        77796.0
# Cromwell          32139.0
# Danbury           92772.0
# Danielson         76167.0
# Enfield           80280.0
# Fairfield        113130.0
# Farmington        78246.0
# Hamden           102699.0
# Hartford          90805.5
# Manchester        78345.0
# Middletown       106654.5
# New Britain       89910.0
# New Haven        110205.0
# New London        98874.0
# Norwalk           73368.0
# Norwich           74916.0
# Old Lyme          34038.0
# Southington       52524.0
# Storrs           140652.0
# Waterbury         84784.5
# West Hartford     90558.0
# West Haven       110907.0
# Willimantic       86139.0
# Winsted           77499.0
# Name: Average Professor, dtype: float64
